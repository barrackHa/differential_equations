# %%
# %matplotlib widget
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import models as m

# %%
## Pitchfork
time = np.arange(0, 9, 0.001)
r0 = -3
x0 = 0.1
a = 25
epsilon = 1.5
sigma = 0.5
config = {
    'time': time,
    'y0': [x0, r0],
    'epsilon': epsilon,
    'sigma_noise': [sigma, 0],
    'a': a,
    'ttl': r"Pitchfork: $\dot{x}$ = rx - $ax^3$,    $\dot{r}$ = $\epsilon$" + "\n" 
}

fig, axs = plt.subplots(1,1)

for i in range(10):
    scp_model = m.SuperCriticalPitchfork()
    res, des = scp_model.simulate(config=config)
    fig, axs, t_star = scp_model.plot(fig=fig, axs=axs)
plt.show()
# Out:
# 100%|██████████| 8999/8999 [00:00<00:00, 53845.24it/s]
# 100%|██████████| 8999/8999 [00:00<00:00, 57875.40it/s]
# 100%|██████████| 8999/8999 [00:00<00:00, 68290.70it/s]
# 100%|██████████| 8999/8999 [00:00<00:00, 65907.00it/s]
# 100%|██████████| 8999/8999 [00:00<00:00, 58347.16it/s]
# 100%|██████████| 8999/8999 [00:00<00:00, 34316.93it/s]
# 100%|██████████| 8999/8999 [00:00<00:00, 33366.84it/s]
# 100%|██████████| 8999/8999 [00:00<00:00, 66486.89it/s]
# 100%|██████████| 8999/8999 [00:00<00:00, 70619.18it/s]
# 100%|██████████| 8999/8999 [00:00<00:00, 70341.49it/s]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
## Saddle Node

time = np.arange(0, 1000, 0.1)
r0 = -0.5
x0 = 0.01
a = 4 #
epsilon = 0.001
sigma = 0.04 #

ttl = r"Saddle Node: $\dot{x}$ = r + a$x^2$ - $x^3$,    $\dot{r}$ = $\epsilon$" + "\n"

config = {
    'time': time,
    'y0': [x0, r0],
    'epsilon': epsilon,
    'sigma_noise': [sigma, 0],
    'a': a,
    'ttl': ttl
}


fig, axs = plt.subplots(1,1)
for i in range(10):
    sd_model = m.SaddleNodeEwsPaperModel()
    res, des = sd_model.simulate(config=config)
    fig, axs, t_star = sd_model.plot(fig=fig, axs=axs)
plt.show()
# Out:
# 100%|██████████| 9999/9999 [00:00<00:00, 67164.27it/s]
# 100%|██████████| 9999/9999 [00:00<00:00, 69530.26it/s]
# 100%|██████████| 9999/9999 [00:00<00:00, 66870.83it/s]
# 100%|██████████| 9999/9999 [00:00<00:00, 61457.50it/s]
# 100%|██████████| 9999/9999 [00:00<00:00, 66308.99it/s]
# 100%|██████████| 9999/9999 [00:00<00:00, 38364.57it/s]
# 100%|██████████| 9999/9999 [00:00<00:00, 65231.52it/s]
# 100%|██████████| 9999/9999 [00:00<00:00, 68859.45it/s]
# 100%|██████████| 9999/9999 [00:00<00:00, 69282.50it/s]
# 100%|██████████| 9999/9999 [00:00<00:00, 69530.72it/s]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
